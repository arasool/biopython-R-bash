# %% [markdown]
# **Project 1**
#
# Our goal for this project will be to identify the various factors that may influence admission into graduate school. It contains four variables- admit, gre, gpa, rank.
#
# 'admit' is a binary variable. It indicates whether or not a candidate was admitted admit =1) our not (admit= 0)
# 'gre' is GRE score
# 'gpa' stands for Grade Point Average
# 'rank' is the rank of an applicant's undergraduate alma mater, with 1 being the highest and 4 as the lowest.

# %% [markdown]
# 1. **Create a data dictionary**

# %% [markdown]
# ![Screen%20Shot%202017-07-31%20at%204.05.43%20PM.png](attachment:Screen%20Shot%202017-07-31%20at%204.05.43%20PM.png)

# %% [markdown]
# **Create a data dictionary**

# %% [markdown]
# ![Screen%20Shot%202017-07-31%20at%205.08.54%20PM.png](attachment:Screen%20Shot%202017-07-31%20at%205.08.54%20PM.png)

# %% [markdown]
# **What are the outcomes, predictors/covariates, relevant timeframe?**
# The outcomes of interest include "admit" which determines number of applicants admitted (1) or not admitted (0).
# The covariates of interest that could affect the state of admission include GRE and GPA scores. And also the prestige of undergrad alma mater, from which the student applied.
# Relevant timeframe was not provided. But since the article attached to the dataset was published in 2013, and the highest score for GRE exams is less than 350 in current time, I would assume that the timeframe is January - May for any year before 2013. Most graduate schools keep December as their deadline for PhD programs, and all the scores (from GPA and GRE) have to sent around the time of application deadline for consideration.

# %% [markdown]
# **Hypothesis, proper statement**
#
# Based on the data, I would like to study the affect of prestige / rank on the possiblity of getting admission.
# "Test whether the prestige of undergrad alma matter positively affect the outcome of admission".

# %% [markdown]
# **What are the goals of the exploratory analysis?**
# The goal of my analysis is the to determine the effect of rank over admission. It is assumed here that higher rank (1,2) led to more admits (1) than lower ranks. I am going to explore that probability. I am also going to determine whether GRE or GPA scores need to be involved in order to study the corellation beteween rank and admit.

# %% [markdown]
# **What are the assumptions regarding the distribution of the data?**
# The assumptions on data distribution are made based on the chart above in data dictionary and on the following image:
#
# ![Screen%20Shot%202017-07-31%20at%204.42.41%20PM.png](attachment:Screen%20Shot%202017-07-31%20at%204.42.41%20PM.png)

# %% [markdown]
# The above image shows the data summary (collected here from R, but can also be collected using describe function, or 'statsmodels'for deeper exploration). There are 127 admits, and only 61 applicants from highest ranking schools. There were also 150 applicants from second highest ranking school. It is my assumption that these two ranks provided the highest probability of admission. Of course I will need to access the GPA and GRE scores from these two ranks as well. It is possible that some applicants went to prestigious schools but didn't produce good enough scores to receive an admission.

# %% [markdown]
# **Data distribution and outliers**
# Data distribution can be determined from data description function and plots such as histograms and boxplots. These plots and function tell us where majority of data points lie, what is an average GPA, GRE score in most and least prestigious schools; whether number of positive admits where evenly distributed among all 4 ranks, or they lied heavily in upper level ranks (like we assumed). Boxplot can provide us the median of the data and quartile ranges, it will also produce the outliers outside the box, in both directions. We might have to exclude the outliers, if they are extreme / exceptional, to get the sense of rest of the data. The outliers could be: gettting very few admits from ranks 1 and rank 4, helped out by the expceptional GPA and GRE scores.

# %% [markdown]
# **What is your exploratory analysis plan?**

# %% [markdown]
# 1. Upload the admissions.csv as a dataframe using pandas.
# 2. get data summary from describe function.
# 3. Use numpy to perform basic mathematical analysis.
# 4. Study all columns for outliers and missing values.
# 5. Create plots such as histograms and boxplot for each column to help with previous step. (matplotlib and seaborn should help in python).
# 6. Determine if the rows with the outliers and missing values need to be removed for better analysis.
# 7. Perform tests to get a correlation between 'admit' and 'prestige'. If the correlation is too weak, run the test with GPA and GRE column against admit and prestige. Maybe admit and prestige do not have a direct link, but higher or lower scores from students of these schools determine their chances of success and failure.
